# %%
import sys
import os
import subprocess
import glob
import fnmatch
import pandas as pd
import seaborn as sns
import matplotlib
# %matplotlib inline

# %%
data_frames = []
path = r'/cluster/work/grlab/projects/Projects2019_SOCIBP/alignment/RNA-SeqC/*'
all_files = glob.glob(os.path.join(path, "*.tsv")) 
for filename in all_files:
    name = os.path.basename(os.path.normpath(filename))
    df = pd.DataFrame.from_csv(filename,sep='\t')
    data_frames.append(df)
    merged = pd.concat(data_frames, axis=1)
    #merged.rename(columns=lambda x: x.split('_')[0], inplace=True)
merged_long=pd.DataFrame.transpose(merged)
#merged_long.to_csv("/cluster/work/grlab/projects/Projects2019_SOCIBP/alignment/RNA-SeqC/aggrgate_RNA-seqc.tsv",sep='\t',index=True)
merged_long_melt=pd.melt(merged_long.reset_index(), id_vars='index')
merged_long_melt.rename(columns={"index":"samples","Sample":"quality_metrics"},inplace=True)
merged_long_melt
# Out:
# /cluster/home/aalva/software/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#                                             samples        quality_metrics  \
# 0              JM-2_L1Aligned.sortedByCoord.out.bam           Mapping Rate
# 1          MM909432_L1Aligned.sortedByCoord.out.bam           Mapping Rate
# 2            T1015A_L1Aligned.sortedByCoord.out.bam           Mapping Rate
# 3          MM170111_L1Aligned.sortedByCoord.out.bam           Mapping Rate
# 4          GY150806_L1Aligned.sortedByCoord.out.bam           Mapping Rate
# 5      C3N-02671_08_L1Aligned.sortedByCoord.out.bam           Mapping Rate
# 6              JM-2_L1Aligned.sortedByCoord.out.bam           Mapping Rate
# 7      C3N-02671_10_L1Aligned.sortedByCoord.out.bam           Mapping Rate
# 8     C3N-02289_4_5_L1Aligned.sortedByCoord.out.bam           Mapping Rate
# 9             Me275_L1Aligned.sortedByCoord.out.bam           Mapping Rate
# 10            EOC04_L1Aligned.sortedByCoord.out.bam           Mapping Rate
# 11           T1185B_L1Aligned.sortedByCoord.out.bam           Mapping Rate
# 12            RCC16_L1Aligned.sortedByCoord.out.bam           Mapping Rate
# 13     C3N-02289_10_L1Aligned.sortedByCoord.out.bam           Mapping Rate
# 14            Me290_L1Aligned.sortedByCoord.out.bam           Mapping Rate
# 15            RCC14_L1Aligned.sortedByCoord.out.bam           Mapping Rate
# 16         MM909362_L1Aligned.sortedByCoord.out.bam           Mapping Rate
# 17             JM-2_L1Aligned.sortedByCoord.out.bam  Unique Rate of Mapped
# 18         MM909432_L1Aligned.sortedByCoord.out.bam  Unique Rate of Mapped
# 19           T1015A_L1Aligned.sortedByCoord.out.bam  Unique Rate of Mapped
# 20         MM170111_L1Aligned.sortedByCoord.out.bam  Unique Rate of Mapped
# 21         GY150806_L1Aligned.sortedByCoord.out.bam  Unique Rate of Mapped
# 22     C3N-02671_08_L1Aligned.sortedByCoord.out.bam  Unique Rate of Mapped
# 23             JM-2_L1Aligned.sortedByCoord.out.bam  Unique Rate of Mapped
# 24     C3N-02671_10_L1Aligned.sortedByCoord.out.bam  Unique Rate of Mapped
# 25    C3N-02289_4_5_L1Aligned.sortedByCoord.out.bam  Unique Rate of Mapped
# 26            Me275_L1Aligned.sortedByCoord.out.bam  Unique Rate of Mapped
# 27            EOC04_L1Aligned.sortedByCoord.out.bam  Unique Rate of Mapped
# 28           T1185B_L1Aligned.sortedByCoord.out.bam  Unique Rate of Mapped
# 29            RCC16_L1Aligned.sortedByCoord.out.bam  Unique Rate of Mapped
# ...                                             ...                    ...
# 1245       GY150806_L1Aligned.sortedByCoord.out.bam         Median Exon CV
# 1246   C3N-02671_08_L1Aligned.sortedByCoord.out.bam         Median Exon CV
# 1247           JM-2_L1Aligned.sortedByCoord.out.bam         Median Exon CV
# 1248   C3N-02671_10_L1Aligned.sortedByCoord.out.bam         Median Exon CV
# 1249  C3N-02289_4_5_L1Aligned.sortedByCoord.out.bam         Median Exon CV
# 1250          Me275_L1Aligned.sortedByCoord.out.bam         Median Exon CV
# 1251          EOC04_L1Aligned.sortedByCoord.out.bam         Median Exon CV
# 1252         T1185B_L1Aligned.sortedByCoord.out.bam         Median Exon CV
# 1253          RCC16_L1Aligned.sortedByCoord.out.bam         Median Exon CV
# 1254   C3N-02289_10_L1Aligned.sortedByCoord.out.bam         Median Exon CV
# 1255          Me290_L1Aligned.sortedByCoord.out.bam         Median Exon CV
# 1256          RCC14_L1Aligned.sortedByCoord.out.bam         Median Exon CV
# 1257       MM909362_L1Aligned.sortedByCoord.out.bam         Median Exon CV
# 1258           JM-2_L1Aligned.sortedByCoord.out.bam            Exon CV MAD
# 1259       MM909432_L1Aligned.sortedByCoord.out.bam            Exon CV MAD
# 1260         T1015A_L1Aligned.sortedByCoord.out.bam            Exon CV MAD
# 1261       MM170111_L1Aligned.sortedByCoord.out.bam            Exon CV MAD
# 1262       GY150806_L1Aligned.sortedByCoord.out.bam            Exon CV MAD
# 1263   C3N-02671_08_L1Aligned.sortedByCoord.out.bam            Exon CV MAD
# 1264           JM-2_L1Aligned.sortedByCoord.out.bam            Exon CV MAD
# 1265   C3N-02671_10_L1Aligned.sortedByCoord.out.bam            Exon CV MAD
# 1266  C3N-02289_4_5_L1Aligned.sortedByCoord.out.bam            Exon CV MAD
# 1267          Me275_L1Aligned.sortedByCoord.out.bam            Exon CV MAD
# 1268          EOC04_L1Aligned.sortedByCoord.out.bam            Exon CV MAD
# 1269         T1185B_L1Aligned.sortedByCoord.out.bam            Exon CV MAD
# 1270          RCC16_L1Aligned.sortedByCoord.out.bam            Exon CV MAD
# 1271   C3N-02289_10_L1Aligned.sortedByCoord.out.bam            Exon CV MAD
# 1272          Me290_L1Aligned.sortedByCoord.out.bam            Exon CV MAD
# 1273          RCC14_L1Aligned.sortedByCoord.out.bam            Exon CV MAD
# 1274       MM909362_L1Aligned.sortedByCoord.out.bam            Exon CV MAD
#
#          value
# 0     1.000000
# 1     1.000000
# 2     1.000000
# 3     1.000000
# 4     1.000000
# 5     1.000000
# 6     1.000000
# 7     1.000000
# 8     1.000000
# 9     1.000000
# 10    1.000000
# 11    1.000000
# 12    1.000000
# 13    1.000000
# 14    1.000000
# 15    1.000000
# 16    1.000000
# 17    1.000000
# 18    1.000000
# 19    1.000000
# 20    1.000000
# 21    1.000000
# 22    1.000000
# 23    1.000000
# 24    1.000000
# 25    1.000000
# 26    1.000000
# 27    1.000000
# 28    1.000000
# 29    1.000000
# ...        ...
# 1245  0.712906
# 1246  0.677816
# 1247  0.818435
# 1248  0.832508
# 1249  0.999696
# 1250  0.604859
# 1251  0.789786
# 1252  0.604955
# 1253  0.543767
# 1254  0.993995
# 1255  0.832508
# 1256  0.585164
# 1257  0.795019
# 1258  1.013700
# 1259  0.535625
# 1260  0.647645
# 1261  0.603582
# 1262  0.364286
# 1263  0.663291
# 1264  1.013700
# 1265  0.947974
# 1266  0.726859
# 1267  0.476120
# 1268  0.687917
# 1269  0.347217
# 1270  0.250714
# 1271  1.093580
# 1272  0.862908
# 1273  0.357146
# 1274  0.626330
#
# [1275 rows x 3 columns]

# %%
sns.catplot(x="samples", y="quality_metrics", linestyles=["-", "--"],kind="point", data=merged_long_melt);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-24107bebbcb4> in <module>
# ----> 1 sns.catplot(x="samples", y="quality_metrics", linestyles=["-", "--"],kind="point", data=merged_long_melt);
#
# AttributeError: module 'seaborn' has no attribute 'catplot'
